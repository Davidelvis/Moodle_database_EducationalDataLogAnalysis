# %% [markdown]
# # Moodle Database: Educational Data Log Analysis

# %% [markdown]
# ## Analysing the 2019 10 Academy learners activity in the Moodle Learning Management System.

# %% [markdown]
# ## Business Need
#
# Many educational facilities such as colleges, universities, bootcamps rely on scalable and versatile Learning Management Systems.
# The Moodle LMS  is a free and open-source learning management system written in PHP and distributed under the GNU General Public License. It is used for blended learning, distance education, flipped classroom and other e-learning projects in schools, universities, workplaces and other sectors. With customizable management features, it is used to create private websites with online courses for educators and trainers to achieve learning goals. Moodle allows for extending and tailoring learning environments using community-sourced plugins.
# In 2019, 10 Academy used the Moodle LMS to manage about 1000 students in their 6 months data science training. Learners, course instructors, and all admins interacted with the Moodle system for almost all the training activities. All events from these activities are logged in the moodle postgres database.
# 10 Academy, like any other educational facility, is interested to understand the learners skill and knowledge development, and is interested to build models that are able to predict possible dropouts as well as classify learners into doing, well, doing ok, and struggling groups. 10 Academy is also interested in automating the process of reminding learners approaching deadlines, providing quick feedback based on their overall community engagement and performance. Moreover, given the main goal of 10 Academy training is to make students job ready, it wants to measure students' performance across many relevant metrics.

# %%
#Installing psycopg2 which  is a DB API 2.0 compliant PostgreSQL driver
# !pip install psycopg2
# Out:
# Collecting psycopg2
#   Downloading https://files.pythonhosted.org/packages/44/1f/a6ae3527568bb9a3d49339beb630ede2dcb345c88cc3cdc2a6dfbb78110e/psycopg2-2.8.6-cp37-cp37m-win_amd64.whl (1.1MB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.8.6

# %%
#installing pgspecial to run the ‘backslash’ commands like in psql
# !pip install pgspecial
# Out:
# Collecting pgspecial
#   Downloading https://files.pythonhosted.org/packages/34/70/f20df1e335592ace0e4f54989307d1630163445599b6abd43a2e0149d483/pgspecial-1.11.10-py3-none-any.whl
# Requirement already satisfied: click>=4.1 in c:\programdata\anaconda3\lib\site-packages (from pgspecial) (7.0)
# Requirement already satisfied: sqlparse>=0.1.19 in c:\programdata\anaconda3\lib\site-packages (from pgspecial) (0.3.1)
# Requirement already satisfied: psycopg2>=2.7.4 in c:\programdata\anaconda3\lib\site-packages (from pgspecial) (2.8.6)
# Installing collected packages: pgspecial
# Successfully installed pgspecial-1.11.10

# %%
#Installing ipython -sql to help us query in jupyter
# !pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading https://files.pythonhosted.org/packages/ab/3d/0d38357c620df31cebb056ca1804027112e5c008f4c2c0e16d879996ad9f/ipython_sql-0.4.0-py3-none-any.whl
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (1.12.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Collecting sqlparse (from ipython-sql)
#   Downloading https://files.pythonhosted.org/packages/85/ee/6e821932f413a5c4b76be9c5936e313e4fc626b33f16e027866e1d60f588/sqlparse-0.3.1-py2.py3-none-any.whl (40kB)
# Requirement already satisfied: ipython>=1.0 in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (7.4.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\programdata\anaconda3\lib\site-packages (from ipython-sql) (1.3.1)
# Collecting prettytable<1 (from ipython-sql)
#   Downloading https://files.pythonhosted.org/packages/ef/30/4b0746848746ed5941f052479e7c23d2b56d174b82f4fd34a25e389831f5/prettytable-0.7.2.tar.bz2
# Requirement already satisfied: jedi>=0.10 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.13.3)
# Requirement already satisfied: setuptools>=18.5 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (49.2.1)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (4.4.0)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (4.3.2)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.3.1)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.1.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.0.9)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\programdata\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.1)
# Requirement already satisfied: parso>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.10->ipython>=1.0->ipython-sql) (0.3.4)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.1.7)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\dclinton\AppData\Local\pip\Cache\wheels\80\34\1c\3967380d9676d162cb59513bd9dc862d0584e045a162095606
# Successfully built prettytable
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.4.0 prettytable-0.7.2 sqlparse-0.3.1

# %%
#importing psycopg2
import psycopg2
import pandas as pd

# %%
#connecting
conn = psycopg2.connect(host="localhost", port = 5432, database="moodle1", user="postgres",password='Komboelvis01')

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#%sql postgresql://postgres:1234@localhost/moodle
# %sql postgresql://postgres:Komboelvis01@localhost/moodle1

# %% [markdown]
# You can also connect using sqlalchemy by importing create_engine from sqlalchemy.
# Below is a code to help in connecting

# %%
'''from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:Komboelvis01:1234@localhost/moodle')'''

# %% [markdown]
# After connecting our postgres database, specifically to the database where the moodle log data is stored, we can start querying from the notebook

# %% [markdown]
# 1. SQL script to count the number of tables in our database

# %%
# %%sql
#
# select count(*)
# from information_schema.tables;
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 1 rows affected.
# [(642,)]

# %% [markdown]
# 2. SQL script to count the number of records in each of the tables given in the MIT section

# %%
# %%sql
# select table_schema,
#        table_name,
#        (xpath('/row/cnt/text()', xml_count))[1]::text::int as row_count
# from (
#   select table_name, table_schema,
#          query_to_xml(format('select count(*) as cnt from %I.%I', table_schema, table_name), false, true, '') as xml_count
#   from information_schema.tables
# ) t
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 642 rows affected.
# [('public', 'mdl_analytics_indicator_calc', 34),
#  ('public', 'mdl_analytics_models', 2),
#  ('public', 'mdl_analytics_models_log', 0),
#  ('public', 'mdl_analytics_predict_samples', 1),
#  ('public', 'mdl_analytics_prediction_actions', 10),
#  ('public', 'mdl_analytics_predictions', 17),
#  ('public', 'mdl_analytics_train_samples', 0),
#  ('public', 'mdl_analytics_used_analysables', 1),
#  ('public', 'mdl_analytics_used_files', 10),
#  ('public', 'mdl_assign', 63),
#  ('public', 'mdl_assign_grades', 15),
#  ('pg_catalog', 'pg_statistic', 1349),
#  ('pg_catalog', 'pg_type', 2006),
#  ('public', 'mdl_assign_overrides', 0),
#  ('public', 'mdl_assign_plugin_config', 436),
#  ('public', 'mdl_assign_submission', 127),
#  ('public', 'mdl_assign_user_flags', 0),
#  ('public', 'mdl_assign_user_mapping', 1763),
#  ('public', 'mdl_assignfeedback_comments', 4),
#  ('public', 'mdl_assignfeedback_editpdf_annot', 0),
#  ('pg_catalog', 'pg_foreign_server', 0),
#  ('pg_catalog', 'pg_authid', 9),
#  ('public', 'mdl_assignfeedback_editpdf_cmnt', 0),
#  ('pg_catalog', 'pg_shadow', 1),
#  ('public', 'mdl_assignfeedback_editpdf_queue', 0),
#  ('public', 'mdl_assignfeedback_editpdf_quick', 0),
#  ('public', 'mdl_assignfeedback_file', 0),
#  ('public', 'mdl_assignment', 0),
#  ('pg_catalog', 'pg_statistic_ext_data', 0),
#  ('pg_catalog', 'pg_roles', 9),
#  ('public', 'mdl_assignment_submissions', 0),
#  ('public', 'mdl_assignment_upgrade', 7),
#  ('public', 'mdl_assignsubmission_file', 12),
#  ('pg_catalog', 'pg_settings', 314),
#  ('public', 'mdl_assignsubmission_onlinetext', 8),
#  ('pg_catalog', 'pg_file_settings', 18),
#  ('pg_catalog', 'pg_hba_file_rules', 4),
#  ('public', 'mdl_auth_oauth2_linked_login', 0),
#  ('pg_catalog', 'pg_config', 23),
#  ('public', 'mdl_backup_controllers', 24),
#  ('public', 'mdl_backup_courses', 0),
#  ('public', 'mdl_backup_logs', 0),
#  ('public', 'mdl_badge', 12),
#  ('public', 'mdl_badge_backpack', 5),
#  ('public', 'mdl_badge_competencies', 0),
#  ('pg_catalog', 'pg_cursors', 0),
#  ('public', 'mdl_badge_criteria', 26),
#  ('public', 'mdl_badge_criteria_met', 3142),
#  ('pg_catalog', 'pg_user_mapping', 0),
#  ('pg_catalog', 'pg_stat_bgwriter', 1),
#  ('pg_catalog', 'pg_replication_origin_status', 0),
#  ('pg_catalog', 'pg_subscription', 0),
#  ('public', 'mdl_badge_criteria_param', 59),
#  ('pg_catalog', 'pg_stat_progress_vacuum', 0),
#  ('pg_catalog', 'pg_stat_progress_cluster', 0),
#  ('pg_catalog', 'pg_attribute', 18051),
#  ('pg_catalog', 'pg_proc', 2960),
#  ('pg_catalog', 'pg_class', 3120),
#  ('pg_catalog', 'pg_attrdef', 2425),
#  ('pg_catalog', 'pg_constraint', 449),
#  ('pg_catalog', 'pg_inherits', 0),
#  ('pg_catalog', 'pg_index', 1732),
#  ('pg_catalog', 'pg_operator', 770),
#  ('pg_catalog', 'pg_opfamily', 107),
#  ('pg_catalog', 'pg_opclass', 128),
#  ('pg_catalog', 'pg_am', 7),
#  ('pg_catalog', 'pg_amop', 715),
#  ('pg_catalog', 'pg_amproc', 447),
#  ('pg_catalog', 'pg_language', 4),
#  ('pg_catalog', 'pg_largeobject_metadata', 0),
#  ('pg_catalog', 'pg_aggregate', 136),
#  ('pg_catalog', 'pg_stat_progress_create_index', 0),
#  ('pg_catalog', 'pg_user_mappings', 0),
#  ('pg_catalog', 'pg_largeobject', 0),
#  ('public', 'mdl_badge_endorsement', 0),
#  ('public', 'mdl_badge_external', 0),
#  ('pg_catalog', 'pg_statistic_ext', 0),
#  ('pg_catalog', 'pg_rewrite', 126),
#  ('pg_catalog', 'pg_trigger', 0),
#  ('pg_catalog', 'pg_event_trigger', 0),
#  ('pg_catalog', 'pg_description', 5086),
#  ('pg_catalog', 'pg_cast', 216),
#  ('pg_catalog', 'pg_enum', 0),
#  ('pg_catalog', 'pg_namespace', 6),
#  ('pg_catalog', 'pg_conversion', 132),
#  ('pg_catalog', 'pg_depend', 16237),
#  ('pg_catalog', 'pg_database', 5),
#  ('pg_catalog', 'pg_db_role_setting', 0),
#  ('pg_catalog', 'pg_tablespace', 2),
#  ('pg_catalog', 'pg_pltemplate', 8),
#  ('pg_catalog', 'pg_auth_members', 3),
#  ('pg_catalog', 'pg_shdepend', 9),
#  ('pg_catalog', 'pg_shdescription', 3),
#  ('pg_catalog', 'pg_ts_config', 22),
#  ('pg_catalog', 'pg_ts_config_map', 418),
#  ('pg_catalog', 'pg_ts_dict', 22),
#  ('pg_catalog', 'pg_ts_parser', 1),
#  ('pg_catalog', 'pg_ts_template', 5),
#  ('pg_catalog', 'pg_extension', 1),
#  ('pg_catalog', 'pg_foreign_data_wrapper', 0),
#  ('pg_catalog', 'pg_foreign_table', 0),
#  ('pg_catalog', 'pg_policy', 0),
#  ('pg_catalog', 'pg_replication_origin', 0),
#  ('pg_catalog', 'pg_default_acl', 0),
#  ('pg_catalog', 'pg_init_privs', 171),
#  ('pg_catalog', 'pg_seclabel', 0),
#  ('pg_catalog', 'pg_shseclabel', 0),
#  ('pg_catalog', 'pg_collation', 650),
#  ('pg_catalog', 'pg_partitioned_table', 0),
#  ('pg_catalog', 'pg_range', 6),
#  ('pg_catalog', 'pg_transform', 0),
#  ('pg_catalog', 'pg_sequence', 446),
#  ('pg_catalog', 'pg_publication', 0),
#  ('pg_catalog', 'pg_publication_rel', 0),
#  ('pg_catalog', 'pg_subscription_rel', 0),
#  ('pg_catalog', 'pg_group', 8),
#  ('pg_catalog', 'pg_user', 1),
#  ('pg_catalog', 'pg_policies', 0),
#  ('pg_catalog', 'pg_rules', 2),
#  ('pg_catalog', 'pg_views', 124),
#  ('pg_catalog', 'pg_tables', 518),
#  ('pg_catalog', 'pg_matviews', 0),
#  ('pg_catalog', 'pg_indexes', 1432),
#  ('pg_catalog', 'pg_sequences', 446),
#  ('pg_catalog', 'pg_stats', 1349),
#  ('pg_catalog', 'pg_stats_ext', 0),
#  ('pg_catalog', 'pg_publication_tables', 0),
#  ('pg_catalog', 'pg_locks', 822),
#  ('pg_catalog', 'pg_available_extensions', 80),
#  ('pg_catalog', 'pg_available_extension_versions', 111),
#  ('pg_catalog', 'pg_prepared_xacts', 0),
#  ('pg_catalog', 'pg_prepared_statements', 0),
#  ('pg_catalog', 'pg_seclabels', 0),
#  ('pg_catalog', 'pg_statio_sys_tables', 370),
#  ('pg_catalog', 'pg_timezone_abbrevs', 196),
#  ('pg_catalog', 'pg_timezone_names', 595),
#  ('pg_catalog', 'pg_statio_user_tables', 448),
#  ('pg_catalog', 'pg_stat_all_tables', 818),
#  ('pg_catalog', 'pg_stat_xact_all_tables', 818),
#  ('pg_catalog', 'pg_stat_sys_tables', 370),
#  ('pg_catalog', 'pg_stat_xact_sys_tables', 370),
#  ('pg_catalog', 'pg_stat_user_tables', 448),
#  ('pg_catalog', 'pg_stat_xact_user_tables', 448),
#  ('pg_catalog', 'pg_statio_all_tables', 818),
#  ('pg_catalog', 'pg_stat_all_indexes', 1732),
#  ('pg_catalog', 'pg_stat_sys_indexes', 417),
#  ('pg_catalog', 'pg_stat_user_indexes', 1315),
#  ('pg_catalog', 'pg_statio_all_indexes', 1732),
#  ('pg_catalog', 'pg_statio_sys_indexes', 417),
#  ('pg_catalog', 'pg_statio_user_indexes', 1315),
#  ('pg_catalog', 'pg_statio_all_sequences', 446),
#  ('pg_catalog', 'pg_statio_sys_sequences', 0),
#  ('pg_catalog', 'pg_statio_user_sequences', 446),
#  ('pg_catalog', 'pg_stat_activity', 10),
#  ('pg_catalog', 'pg_stat_replication', 0),
#  ('pg_catalog', 'pg_stat_wal_receiver', 0),
#  ('pg_catalog', 'pg_stat_subscription', 0),
#  ('pg_catalog', 'pg_stat_ssl', 10),
#  ('pg_catalog', 'pg_stat_gssapi', 10),
#  ('pg_catalog', 'pg_replication_slots', 0),
#  ('pg_catalog', 'pg_stat_database', 6),
#  ('pg_catalog', 'pg_stat_database_conflicts', 5),
#  ('pg_catalog', 'pg_stat_user_functions', 0),
#  ('pg_catalog', 'pg_stat_xact_user_functions', 0),
#  ('pg_catalog', 'pg_stat_archiver', 1),
#  ('information_schema', 'information_schema_catalog_name', 1),
#  ('information_schema', 'check_constraint_routine_usage', 0),
#  ('information_schema', 'applicable_roles', 3),
#  ('information_schema', 'administrable_role_authorizations', 0),
#  ('information_schema', 'collation_character_set_applicability', 650),
#  ('information_schema', 'attributes', 0),
#  ('information_schema', 'check_constraints', 3621),
#  ('information_schema', 'character_sets', 1),
#  ('information_schema', 'collations', 650),
#  ('information_schema', 'column_domain_usage', 666),
#  ('information_schema', 'column_column_usage', 0),
#  ('information_schema', 'column_privileges', 25035),
#  ('information_schema', 'column_udt_usage', 5829),
#  ('information_schema', 'columns', 5829),
#  ('information_schema', 'constraint_column_usage', 447),
#  ('information_schema', 'schemata', 6),
#  ('information_schema', 'constraint_table_usage', 447),
#  ('information_schema', 'domain_constraints', 2),
#  ('information_schema', 'sql_packages', 10),
#  ('information_schema', 'domain_udt_usage', 5),
#  ('information_schema', 'sequences', 446),
#  ('information_schema', 'domains', 5),
#  ('information_schema', 'enabled_roles', 9),
#  ('information_schema', 'key_column_usage', 447),
#  ('information_schema', 'parameters', 5825),
#  ('information_schema', 'referential_constraints', 0),
#  ('information_schema', 'sql_features', 716),
#  ('information_schema', 'role_column_grants', 25035),
#  ('information_schema', 'routine_privileges', 5888),
#  ('information_schema', 'role_routine_grants', 5888),
#  ('information_schema', 'routines', 2960),
#  ('information_schema', 'sql_implementation_info', 12),
#  ('information_schema', 'sql_parts', 9),
#  ('information_schema', 'sql_languages', 4),
#  ('information_schema', 'sql_sizing', 23),
#  ('information_schema', 'sql_sizing_profiles', 0),
#  ('information_schema', 'table_constraints', 4066),
#  ('information_schema', 'table_privileges', 4671),
#  ('information_schema', 'role_table_grants', 4671),
#  ('information_schema', 'views', 124),
#  ('information_schema', 'tables', 642),
#  ('information_schema', 'transforms', 0),
#  ('information_schema', 'triggered_update_columns', 0),
#  ('information_schema', '_pg_foreign_servers', 0),
#  ('information_schema', 'triggers', 0),
#  ('information_schema', 'data_type_privileges', 14619),
#  ('information_schema', 'udt_privileges', 2776),
#  ('information_schema', 'role_udt_grants', 2776),
#  ('information_schema', 'usage_privileges', 660),
#  ('information_schema', 'element_types', 260),
#  ('information_schema', 'role_usage_grants', 660),
#  ('information_schema', 'user_defined_types', 0),
#  ('information_schema', '_pg_foreign_table_columns', 0),
#  ('information_schema', 'view_column_usage', 247),
#  ('information_schema', 'view_routine_usage', 31),
#  ('information_schema', 'view_table_usage', 40),
#  ('information_schema', 'foreign_server_options', 0),
#  ('information_schema', 'column_options', 0),
#  ('information_schema', '_pg_foreign_data_wrappers', 0),
#  ('information_schema', 'foreign_data_wrapper_options', 0),
#  ('information_schema', 'foreign_tables', 0),
#  ('information_schema', 'foreign_data_wrappers', 0),
#  ('information_schema', 'foreign_servers', 0),
#  ('information_schema', '_pg_foreign_tables', 0),
#  ('information_schema', 'foreign_table_options', 0),
#  ('information_schema', '_pg_user_mappings', 0),
#  ('information_schema', 'user_mappings', 0),
#  ('information_schema', 'user_mapping_options', 0),
#  ('public', 'mdl_badge_issued', 1560),
#  ('public', 'mdl_badge_manual_award', 0),
#  ('public', 'mdl_badge_related', 3),
#  ('public', 'mdl_block', 46),
#  ('public', 'mdl_block_community', 0),
#  ('public', 'mdl_block_configurable_reports', 21),
#  ('public', 'mdl_block_instances', 3000),
#  ('public', 'mdl_block_positions', 3973),
#  ('public', 'mdl_block_recent_activity', 0),
#  ('public', 'mdl_block_recentlyaccesseditems', 2950),
#  ('public', 'mdl_block_rss_client', 12),
#  ('public', 'mdl_blog_association', 0),
#  ('public', 'mdl_blog_external', 0),
#  ('public', 'mdl_book', 11),
#  ('public', 'mdl_book_chapters', 33),
#  ('public', 'mdl_cache_filters', 0),
#  ('public', 'mdl_cache_flags', 0),
#  ('public', 'mdl_capabilities', 679),
#  ('public', 'mdl_chat', 5),
#  ('public', 'mdl_chat_messages', 561),
#  ('public', 'mdl_chat_messages_current', 0),
#  ('public', 'mdl_chat_users', 0),
#  ('public', 'mdl_choice', 5),
#  ('public', 'mdl_choice_answers', 2),
#  ('public', 'mdl_choice_options', 17),
#  ('public', 'mdl_cohort', 25),
#  ('public', 'mdl_cohort_members', 2053),
#  ('public', 'mdl_comments', 10),
#  ('public', 'mdl_competency', 0),
#  ('public', 'mdl_competency_coursecomp', 0),
#  ('public', 'mdl_competency_coursecompsetting', 0),
#  ('public', 'mdl_competency_evidence', 0),
#  ('public', 'mdl_competency_framework', 0),
#  ('public', 'mdl_competency_modulecomp', 0),
#  ('public', 'mdl_competency_plan', 0),
#  ('public', 'mdl_competency_plancomp', 0),
#  ('public', 'mdl_competency_relatedcomp', 0),
#  ('public', 'mdl_competency_template', 0),
#  ('public', 'mdl_competency_templatecohort', 0),
#  ('public', 'mdl_competency_templatecomp', 0),
#  ('public', 'mdl_competency_usercomp', 0),
#  ('public', 'mdl_competency_usercompcourse', 0),
#  ('public', 'mdl_competency_usercompplan', 0),
#  ('public', 'mdl_competency_userevidence', 0),
#  ('public', 'mdl_competency_userevidencecomp', 0),
#  ('public', 'mdl_config', 491),
#  ('public', 'mdl_config_log', 2923),
#  ('public', 'mdl_config_plugins', 2713),
#  ('public', 'mdl_context', 4359),
#  ('public', 'mdl_context_temp', 0),
#  ('public', 'mdl_course', 15),
#  ('public', 'mdl_course_categories', 9),
#  ('public', 'mdl_course_completion_aggr_methd', 16),
#  ('public', 'mdl_course_completion_crit_compl', 867),
#  ('public', 'mdl_course_completion_criteria', 9),
#  ('public', 'mdl_course_completion_defaults', 0),
#  ('public', 'mdl_course_completions', 9234),
#  ('public', 'mdl_course_format_options', 27),
#  ('public', 'mdl_course_modules', 290),
#  ('public', 'mdl_course_modules_completion', 4483),
#  ('public', 'mdl_course_published', 0),
#  ('public', 'mdl_course_request', 0),
#  ('public', 'mdl_course_sections', 91),
#  ('public', 'mdl_data', 0),
#  ('public', 'mdl_data_content', 0),
#  ('public', 'mdl_data_fields', 0),
#  ('public', 'mdl_data_records', 0),
#  ('public', 'mdl_editor_atto_autosave', 0),
#  ('public', 'mdl_enrol', 74),
#  ('public', 'mdl_enrol_flatfile', 0),
#  ('public', 'mdl_enrol_lti_lti2_consumer', 0),
#  ('public', 'mdl_enrol_lti_lti2_context', 0),
#  ('public', 'mdl_enrol_lti_lti2_nonce', 0),
#  ('public', 'mdl_enrol_lti_lti2_resource_link', 0),
#  ('public', 'mdl_enrol_lti_lti2_share_key', 0),
#  ('public', 'mdl_enrol_lti_lti2_tool_proxy', 0),
#  ('public', 'mdl_enrol_lti_lti2_user_result', 0),
#  ('public', 'mdl_enrol_lti_tool_consumer_map', 0),
#  ('public', 'mdl_enrol_lti_tools', 0),
#  ('public', 'mdl_enrol_lti_users', 0),
#  ('public', 'mdl_enrol_paypal', 0),
#  ('public', 'mdl_event', 23),
#  ('public', 'mdl_event_subscriptions', 0),
#  ('public', 'mdl_events_handlers', 0),
#  ('public', 'mdl_events_queue', 0),
#  ('public', 'mdl_events_queue_handlers', 0),
#  ('public', 'mdl_external_functions', 535),
#  ('public', 'mdl_external_services', 3),
#  ('public', 'mdl_external_services_functions', 343),
#  ('public', 'mdl_external_services_users', 1),
#  ('public', 'mdl_external_tokens', 12),
#  ('public', 'mdl_favourite', 64),
#  ('public', 'mdl_feedback', 9),
#  ('public', 'mdl_feedback_completed', 32),
#  ('public', 'mdl_feedback_completedtmp', 5),
#  ('public', 'mdl_feedback_item', 95),
#  ('public', 'mdl_feedback_sitecourse_map', 0),
#  ('public', 'mdl_feedback_template', 1),
#  ('public', 'mdl_feedback_value', 606),
#  ('public', 'mdl_feedback_valuetmp', 110),
#  ('public', 'mdl_file_conversion', 0),
#  ('public', 'mdl_files', 6243),
#  ('public', 'mdl_files_reference', 1),
#  ('public', 'mdl_filter_active', 13),
#  ('public', 'mdl_filter_config', 0),
#  ('public', 'mdl_folder', 5),
#  ('public', 'mdl_forum', 34),
#  ('public', 'mdl_forum_digests', 2),
#  ('public', 'mdl_forum_discussion_subs', 29),
#  ('public', 'mdl_forum_discussions', 23),
#  ('public', 'mdl_forum_posts', 131),
#  ('public', 'mdl_forum_queue', 0),
#  ('public', 'mdl_forum_read', 0),
#  ('public', 'mdl_forum_subscriptions', 5121),
#  ('public', 'mdl_forum_track_prefs', 0),
#  ('public', 'mdl_glossary', 1),
#  ('public', 'mdl_glossary_alias', 4),
#  ('public', 'mdl_glossary_categories', 0),
#  ('public', 'mdl_glossary_entries', 5),
#  ('public', 'mdl_glossary_entries_categories', 0),
#  ('public', 'mdl_glossary_formats', 7),
#  ('public', 'mdl_grade_categories', 16),
#  ('public', 'mdl_grade_categories_history', 46),
#  ('public', 'mdl_grade_grades', 3643),
#  ('public', 'mdl_grade_grades_history', 7108),
#  ('public', 'mdl_grade_import_newitem', 0),
#  ('public', 'mdl_grade_import_values', 0),
#  ('public', 'mdl_grade_items', 113),
#  ('public', 'mdl_grade_items_history', 486),
#  ('public', 'mdl_grade_letters', 0),
#  ('public', 'mdl_grade_outcomes', 0),
#  ('public', 'mdl_grade_outcomes_courses', 0),
#  ('public', 'mdl_grade_outcomes_history', 0),
#  ('public', 'mdl_grade_settings', 5),
#  ('public', 'mdl_grading_areas', 56),
#  ('public', 'mdl_grading_definitions', 0),
#  ('public', 'mdl_grading_instances', 0),
#  ('public', 'mdl_gradingform_guide_comments', 0),
#  ('public', 'mdl_gradingform_guide_criteria', 0),
#  ('public', 'mdl_gradingform_guide_fillings', 0),
#  ('public', 'mdl_gradingform_rubric_criteria', 0),
#  ('public', 'mdl_gradingform_rubric_fillings', 0),
#  ('public', 'mdl_gradingform_rubric_levels', 0),
#  ('public', 'mdl_groupings', 0),
#  ('public', 'mdl_groupings_groups', 0),
#  ('public', 'mdl_groups', 15),
#  ('public', 'mdl_groups_members', 2535),
#  ('public', 'mdl_hvp', 1),
#  ('public', 'mdl_hvp_auth', 0),
#  ('public', 'mdl_hvp_content_user_data', 0),
#  ('public', 'mdl_hvp_contents_libraries', 14),
#  ('public', 'mdl_hvp_counters', 128),
#  ('public', 'mdl_hvp_events', 0),
#  ('public', 'mdl_hvp_libraries', 102),
#  ('public', 'mdl_hvp_libraries_cachedassets', 75),
#  ('public', 'mdl_hvp_libraries_hub_cache', 43),
#  ('public', 'mdl_hvp_libraries_languages', 1282),
#  ('public', 'mdl_hvp_libraries_libraries', 226),
#  ('public', 'mdl_hvp_tmpfiles', 0),
#  ('public', 'mdl_hvp_xapi_results', 0),
#  ('public', 'mdl_imscp', 0),
#  ('public', 'mdl_label', 17),
#  ('public', 'mdl_lesson', 3),
#  ('public', 'mdl_lesson_answers', 20),
#  ('public', 'mdl_lesson_attempts', 351),
#  ('public', 'mdl_lesson_branch', 3457),
#  ('public', 'mdl_lesson_grades', 194),
#  ('public', 'mdl_lesson_overrides', 0),
#  ('public', 'mdl_lesson_pages', 13),
#  ('public', 'mdl_lesson_timer', 926),
#  ('public', 'mdl_license', 9),
#  ('public', 'mdl_lock_db', 167),
#  ('public', 'mdl_log', 0),
#  ('public', 'mdl_log_display', 192),
#  ('public', 'mdl_log_queries', 0),
#  ('public', 'mdl_logstore_standard_log', 417554),
#  ('public', 'mdl_lti', 0),
#  ('public', 'mdl_lti_submission', 0),
#  ('public', 'mdl_lti_tool_proxies', 0),
#  ('public', 'mdl_lti_tool_settings', 0),
#  ('public', 'mdl_lti_types', 0),
#  ('public', 'mdl_lti_types_config', 0),
#  ('public', 'mdl_ltiservice_gradebookservices', 0),
#  ('public', 'mdl_message', 0),
#  ('public', 'mdl_message_airnotifier_devices', 0),
#  ('public', 'mdl_message_contact_requests', 4),
#  ('public', 'mdl_message_contacts', 12),
#  ('public', 'mdl_message_conversation_members', 799),
#  ('public', 'mdl_message_conversations', 402),
#  ('public', 'mdl_message_popup', 0),
#  ('public', 'mdl_message_popup_notifications', 149529),
#  ('public', 'mdl_message_processors', 4),
#  ('public', 'mdl_message_providers', 40),
#  ('public', 'mdl_message_read', 0),
#  ('public', 'mdl_message_user_actions', 382),
#  ('public', 'mdl_message_users_blocked', 0),
#  ('public', 'mdl_messageinbound_datakeys', 0),
#  ('public', 'mdl_messageinbound_handlers', 3),
#  ('public', 'mdl_messageinbound_messagelist', 0),
#  ('public', 'mdl_messages', 675),
#  ('public', 'mdl_mnet_application', 2),
#  ('public', 'mdl_mnet_host', 3),
#  ('public', 'mdl_mnet_host2service', 4),
#  ('public', 'mdl_mnet_log', 0),
#  ('public', 'mdl_mnet_remote_rpc', 16),
#  ('public', 'mdl_mnet_remote_service2rpc', 16),
#  ('public', 'mdl_mnet_rpc', 15),
#  ('public', 'mdl_mnet_service', 4),
#  ('public', 'mdl_mnet_service2rpc', 15),
#  ('public', 'mdl_mnet_session', 0),
#  ('public', 'mdl_mnet_sso_access_control', 0),
#  ('public', 'mdl_mnetservice_enrol_courses', 0),
#  ('public', 'mdl_mnetservice_enrol_enrolments', 0),
#  ('public', 'mdl_modules', 26),
#  ('public', 'mdl_moodleoverflow', 1),
#  ('public', 'mdl_moodleoverflow_discuss_subs', 4),
#  ('public', 'mdl_moodleoverflow_discussions', 2),
#  ('public', 'mdl_moodleoverflow_posts', 18),
#  ('public', 'mdl_moodleoverflow_ratings', 6),
#  ('public', 'mdl_moodleoverflow_read', 0),
#  ('public', 'mdl_moodleoverflow_subscriptions', 998),
#  ('public', 'mdl_moodleoverflow_tracking', 1),
#  ('public', 'mdl_my_pages', 546),
#  ('public', 'mdl_notifications', 114),
#  ('public', 'mdl_oauth2_access_token', 0),
#  ('public', 'mdl_oauth2_endpoint', 5),
#  ('public', 'mdl_oauth2_issuer', 1),
#  ('public', 'mdl_oauth2_system_account', 0),
#  ('public', 'mdl_oauth2_user_field_mapping', 10),
#  ('public', 'mdl_page', 65),
#  ('public', 'mdl_portfolio_instance', 1),
#  ('public', 'mdl_portfolio_instance_config', 2),
#  ('public', 'mdl_portfolio_instance_user', 2),
#  ('public', 'mdl_portfolio_log', 0),
#  ('public', 'mdl_portfolio_mahara_queue', 0),
#  ('public', 'mdl_portfolio_tempdata', 0),
#  ('public', 'mdl_post', 0),
#  ('public', 'mdl_profiling', 0),
#  ('public', 'mdl_qtype_ddimageortext', 0),
#  ('public', 'mdl_qtype_ddimageortext_drags', 0),
#  ('public', 'mdl_qtype_ddimageortext_drops', 0),
#  ('public', 'mdl_qtype_ddmarker', 0),
#  ('public', 'mdl_qtype_ddmarker_drags', 0),
#  ('public', 'mdl_qtype_ddmarker_drops', 0),
#  ('public', 'mdl_qtype_essay_options', 16),
#  ('public', 'mdl_qtype_match_options', 11),
#  ('public', 'mdl_qtype_match_subquestions', 51),
#  ('public', 'mdl_qtype_multichoice_options', 80),
#  ('public', 'mdl_qtype_randomsamatch_options', 0),
#  ('public', 'mdl_qtype_shortanswer_options', 26),
#  ('public', 'mdl_question', 149),
#  ('public', 'mdl_question_answers', 405),
#  ('public', 'mdl_question_attempt_step_data', 32590),
#  ('public', 'mdl_question_attempt_steps', 27761),
#  ('public', 'mdl_question_attempts', 9738),
#  ('public', 'mdl_question_calculated', 0),
#  ('public', 'mdl_question_calculated_options', 0),
#  ('public', 'mdl_question_categories', 85),
#  ('public', 'mdl_question_dataset_definitions', 0),
#  ('public', 'mdl_question_dataset_items', 0),
#  ('public', 'mdl_question_datasets', 0),
#  ('public', 'mdl_question_ddwtos', 0),
#  ('public', 'mdl_question_gapselect', 0),
#  ('public', 'mdl_question_hints', 1),
#  ('public', 'mdl_question_multianswer', 1),
#  ('public', 'mdl_question_numerical', 5),
#  ('public', 'mdl_question_numerical_options', 5),
#  ('public', 'mdl_question_numerical_units', 0),
#  ('public', 'mdl_question_response_analysis', 0),
#  ('public', 'mdl_question_response_count', 0),
#  ('public', 'mdl_question_statistics', 0),
#  ('public', 'mdl_question_truefalse', 8),
#  ('public', 'mdl_question_usages', 1361),
#  ('public', 'mdl_questionnaire', 6),
#  ('public', 'mdl_questionnaire_dependency', 0),
#  ('public', 'mdl_questionnaire_fb_sections', 0),
#  ('public', 'mdl_questionnaire_feedback', 0),
#  ('public', 'mdl_questionnaire_quest_choice', 308),
#  ('public', 'mdl_questionnaire_question', 66),
#  ('public', 'mdl_questionnaire_question_type', 11),
#  ('public', 'mdl_questionnaire_resp_multiple', 0),
#  ('public', 'mdl_questionnaire_resp_single', 2149),
#  ('public', 'mdl_questionnaire_response', 1221),
#  ('public', 'mdl_questionnaire_response_bool', 306),
#  ('public', 'mdl_questionnaire_response_date', 0),
#  ('public', 'mdl_questionnaire_response_other', 0),
#  ('public', 'mdl_questionnaire_response_rank', 2736),
#  ('public', 'mdl_questionnaire_response_text', 4115),
#  ('public', 'mdl_questionnaire_survey', 6),
#  ('public', 'mdl_quiz', 25),
#  ('public', 'mdl_quiz_attempts', 1361),
#  ('public', 'mdl_quiz_feedback', 27),
#  ('public', 'mdl_quiz_grades', 834),
#  ('public', 'mdl_quiz_overrides', 1),
#  ('public', 'mdl_quiz_overview_regrades', 0),
#  ('public', 'mdl_quiz_reports', 4),
#  ('public', 'mdl_quiz_sections', 25),
#  ('public', 'mdl_quiz_slot_tags', 0),
#  ('public', 'mdl_quiz_slots', 125),
#  ('public', 'mdl_quiz_statistics', 0),
#  ('public', 'mdl_rating', 13),
#  ('public', 'mdl_reengagement', 1),
#  ('public', 'mdl_reengagement_inprogress', 0),
#  ('public', 'mdl_registration_hubs', 1),
#  ('public', 'mdl_repository', 8),
#  ('public', 'mdl_repository_instance_config', 0),
#  ('public', 'mdl_repository_instances', 8),
#  ('public', 'mdl_repository_onedrive_access', 0),
#  ('public', 'mdl_resource', 29),
#  ('public', 'mdl_resource_old', 0),
#  ('public', 'mdl_role', 8),
#  ('public', 'mdl_role_allow_assign', 7),
#  ('public', 'mdl_role_allow_override', 11),
#  ('public', 'mdl_role_allow_switch', 9),
#  ('public', 'mdl_role_allow_view', 24),
#  ('public', 'mdl_role_assignments', 12423),
#  ('public', 'mdl_role_capabilities', 1543),
#  ('public', 'mdl_role_context_levels', 14),
#  ('public', 'mdl_role_names', 7),
#  ('public', 'mdl_role_sortorder', 0),
#  ('public', 'mdl_scale', 3),
#  ('public', 'mdl_scale_history', 0),
#  ('public', 'mdl_scorm', 0),
#  ('public', 'mdl_scorm_aicc_session', 0),
#  ('public', 'mdl_scorm_scoes', 0),
#  ('public', 'mdl_scorm_scoes_data', 0),
#  ('public', 'mdl_scorm_scoes_track', 0),
#  ('public', 'mdl_scorm_seq_mapinfo', 0),
#  ('public', 'mdl_scorm_seq_objective', 0),
#  ('public', 'mdl_scorm_seq_rolluprule', 0),
#  ('public', 'mdl_scorm_seq_rolluprulecond', 0),
#  ('public', 'mdl_scorm_seq_rulecond', 0),
#  ('public', 'mdl_scorm_seq_ruleconds', 0),
#  ('public', 'mdl_search_index_requests', 0),
#  ('public', 'mdl_search_simpledb_index', 2974),
#  ('public', 'mdl_sessions', 1),
#  ('public', 'mdl_stats_daily', 1958),
#  ('public', 'mdl_stats_monthly', 125),
#  ('public', 'mdl_stats_user_daily', 1734),
#  ('public', 'mdl_stats_user_monthly', 763),
#  ('public', 'mdl_stats_user_weekly', 1103),
#  ('public', 'mdl_stats_weekly', 341),
#  ('public', 'mdl_survey', 5),
#  ('public', 'mdl_survey_analysis', 0),
#  ('public', 'mdl_survey_answers', 0),
#  ('public', 'mdl_survey_questions', 73),
#  ('public', 'mdl_tag', 93),
#  ('public', 'mdl_tag_area', 11),
#  ('public', 'mdl_tag_coll', 1),
#  ('public', 'mdl_tag_correlation', 0),
#  ('public', 'mdl_tag_instance', 110),
#  ('public', 'mdl_task_adhoc', 0),
#  ('public', 'mdl_task_scheduled', 86),
#  ('public', 'mdl_tool_cohortroles', 3),
#  ('public', 'mdl_tool_customlang', 27960),
#  ('public', 'mdl_tool_customlang_components', 470),
#  ('public', 'mdl_tool_dataprivacy_category', 0),
#  ('public', 'mdl_tool_dataprivacy_ctxexpired', 0),
#  ('public', 'mdl_tool_dataprivacy_ctxinstance', 0),
#  ('public', 'mdl_tool_dataprivacy_ctxlevel', 0),
#  ('public', 'mdl_tool_dataprivacy_purpose', 0),
#  ('public', 'mdl_tool_dataprivacy_purposerole', 0),
#  ('public', 'mdl_tool_dataprivacy_request', 11),
#  ('public', 'mdl_tool_monitor_events', 0),
#  ('public', 'mdl_tool_monitor_history', 0),
#  ('public', 'mdl_tool_monitor_rules', 0),
#  ('public', 'mdl_tool_monitor_subscriptions', 0),
#  ('public', 'mdl_tool_policy', 0),
#  ('public', 'mdl_tool_policy_acceptances', 0),
#  ('public', 'mdl_tool_policy_versions', 0),
#  ('public', 'mdl_tool_recyclebin_category', 0),
#  ('public', 'mdl_tool_recyclebin_course', 0),
#  ('public', 'mdl_tool_usertours_steps', 14),
#  ('public', 'mdl_tool_usertours_tours', 2),
#  ('public', 'mdl_tool_webanalytics', 2),
#  ('public', 'mdl_upgrade_log', 1319),
#  ('public', 'mdl_url', 6),
#  ('public', 'mdl_user', 1052),
#  ('public', 'mdl_user_devices', 13),
#  ('public', 'mdl_user_enrolments', 10388),
#  ('public', 'mdl_user_info_category', 1),
#  ('public', 'mdl_user_info_data', 1743),
#  ('public', 'mdl_user_info_field', 6),
#  ('public', 'mdl_user_lastaccess', 1647),
#  ('public', 'mdl_user_password_history', 0),
#  ('public', 'mdl_user_password_resets', 0),
#  ('public', 'mdl_user_preferences', 4015),
#  ('public', 'mdl_user_private_key', 1642),
#  ('public', 'mdl_wiki', 2),
#  ('public', 'mdl_wiki_links', 3),
#  ('public', 'mdl_wiki_locks', 0),
#  ('public', 'mdl_wiki_pages', 4),
#  ('public', 'mdl_wiki_subwikis', 1),
#  ('public', 'mdl_wiki_synonyms', 0),
#  ('public', 'mdl_wiki_versions', 30),
#  ('public', 'mdl_workshop', 1),
#  ('public', 'mdl_workshop_aggregations', 0),
#  ('public', 'mdl_workshop_assessments', 0),
#  ('public', 'mdl_workshop_grades', 0),
#  ('public', 'mdl_workshop_submissions', 0),
#  ('public', 'mdl_workshopallocation_scheduled', 0),
#  ('public', 'mdl_workshopeval_best_settings', 0),
#  ('public', 'mdl_workshopform_accumulative', 0),
#  ('public', 'mdl_workshopform_comments', 0),
#  ('public', 'mdl_workshopform_numerrors', 0),
#  ('public', 'mdl_workshopform_numerrors_map', 0),
#  ('public', 'mdl_workshopform_rubric', 0),
#  ('public', 'mdl_workshopform_rubric_config', 0),
#  ('public', 'mdl_workshopform_rubric_levels', 0)]

# %% [markdown]
# 3.SQL script to get Monthly usage time of learners who have confirmed and are not deleted

# %%
# %%sql
# --Monthly usage time of learners who have confirmed and are not deleted
# SELECT
# EXTRACT(MONTH FROM to_timestamp(mdl_stats_user_monthly.timeend)) AS calendar_month,
# EXTRACT(YEAR FROM to_timestamp(mdl_stats_user_monthly.timeend)) AS calendar_year,
# mdl_role.name AS user_role,
# COUNT(DISTINCT mdl_stats_user_monthly.userid) AS total_users
# FROM
# mdl_stats_user_monthly
# INNER JOIN mdl_role_assignments ON mdl_stats_user_monthly.userid = mdl_role_assignments.userid
# INNER JOIN mdl_context ON mdl_role_assignments.contextid = mdl_context.id
# INNER JOIN mdl_role ON mdl_role_assignments.roleid = mdl_role.id
# WHERE mdl_context.contextlevel = 50
# AND mdl_stats_user_monthly.stattype = 'activity'
# AND mdl_stats_user_monthly.courseid <>1
# GROUP BY EXTRACT(MONTH FROM to_timestamp(mdl_stats_user_monthly.timeend)),
# EXTRACT(YEAR FROM to_timestamp(mdl_stats_user_monthly.timeend)),
# mdl_stats_user_monthly.stattype,
# mdl_role.name
# ORDER BY
# EXTRACT(YEAR FROM to_timestamp(mdl_stats_user_monthly.timeend)), EXTRACT(MONTH FROM to_timestamp(mdl_stats_user_monthly.timeend)),
# mdl_role.name
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 2 rows affected.
# [(7.0, 2019.0, '', 44), (8.0, 2019.0, '', 121)]

# %% [markdown]
# 3. SQL script to get Monthly usage time of learners who have confirmed and are not deleted

# %%
# %%sql
# SELECT COUNT(lastaccess - firstaccess) AS usagetime,
# EXTRACT (MONTH FROM to_timestamp(firstaccess)) AS month
# FROM mdl_user WHERE confirmed = 1 AND deleted = 0 GROUP BY EXTRACT (MONTH FROM to_timestamp(firstaccess))
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 7 rows affected.
# [(58, 3.0),
#  (31, 7.0),
#  (450, 1.0),
#  (227, 2.0),
#  (27, 6.0),
#  (138, 4.0),
#  (113, 5.0)]

# %% [markdown]
# SQL script to get the Number of quiz submissions by hour of day

# %%
# %%sql
# select  date_part('hour', timestamp with time zone 'epoch' + timefinish * interval '1 second') as hour, count(1)
# from mdl_quiz_attempts qa
# where qa.preview = 0 and qa.timefinish <> 0
# group by date_part('hour', timestamp with time zone 'epoch' + timefinish * interval '1 second')
# order by hour
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 24 rows affected.
# [(0.0, 26),
#  (1.0, 23),
#  (2.0, 30),
#  (3.0, 29),
#  (4.0, 7),
#  (5.0, 14),
#  (6.0, 10),
#  (7.0, 18),
#  (8.0, 17),
#  (9.0, 34),
#  (10.0, 46),
#  (11.0, 69),
#  (12.0, 95),
#  (13.0, 89),
#  (14.0, 104),
#  (15.0, 90),
#  (16.0, 79),
#  (17.0, 69),
#  (18.0, 68),
#  (19.0, 70),
#  (20.0, 57),
#  (21.0, 55),
#  (22.0, 46),
#  (23.0, 54)]

# %% [markdown]
# 4. SQL script to get the Number of quizz per course

# %%
#Number of quizz per course
# %%sql
SELECT COUNT(*)
,concat('<a target="_new" href="%%WWWROOT%%/course/view.php?id=',c.id,'">',c.fullname,'</a>') AS Course
,concat('<a target="_new" href="%%WWWROOT%%/mod/quiz/index.php?id=',c.id,'">Link</a>') AS Quizes
 
FROM mdl_course_modules cm
JOIN mdl_course c ON c.id = cm.course
JOIN mdl_modules AS m ON m.id = cm.module
WHERE m.name LIKE 'quiz'
GROUP BY c.id
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 7 rows affected.
# [(10, '<a target="_new" href="%%WWWROOT%%/course/view.php?id=9">Python for Beginners 1 - Python Language Basics</a>', '<a target="_new" href="%%WWWROOT%%/mod/quiz/index.php?id=9">Link</a>'),
#  (4, '<a target="_new" href="%%WWWROOT%%/course/view.php?id=7">FDP Design -WordPress</a>', '<a target="_new" href="%%WWWROOT%%/mod/quiz/index.php?id=7">Link</a>'),
#  (1, '<a target="_new" href="%%WWWROOT%%/course/view.php?id=45">Pattern Match (new)</a>', '<a target="_new" href="%%WWWROOT%%/mod/quiz/index.php?id=45">Link</a>'),
#  (7, '<a target="_new" href="%%WWWROOT%%/course/view.php?id=50">How data can impact development</a>', '<a target="_new" href="%%WWWROOT%%/mod/quiz/index.php?id=50">Link</a>'),
#  (1, '<a target="_new" href="%%WWWROOT%%/course/view.php?id=46">Welcome to UpSkill - start here!</a>', '<a target="_new" href="%%WWWROOT%%/mod/quiz/index.php?id=46">Link</a>'),
#  (1, '<a target="_new" href="%%WWWROOT%%/course/view.php?id=47">Fundamentals of Data Science</a>', '<a target="_new" href="%%WWWROOT%%/mod/quiz/index.php?id=47">Link</a>'),
#  (1, '<a target="_new" href="%%WWWROOT%%/course/view.php?id=12">Pattern Match</a>', '<a target="_new" href="%%WWWROOT%%/mod/quiz/index.php?id=12">Link</a>')]

# %%
# %%sql
# --Count of log events per user for the following verbs 1.Loggedin
# SELECT u.id,
#  COUNT(*) AS logins
# FROM mdl_logstore_standard_log l
# join mdl_user u on u.id = l.userid
# WHERE l.action = 'loggedin'
# group by u.id
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 600 rows affected.
# [(1, 1),
#  (2, 169),
#  (3, 107),
#  (5, 54),
#  (7, 3),
#  (8, 2),
#  (9, 13),
#  (15, 5),
#  (16, 5),
#  (19, 2),
#  (20, 2),
#  (22, 1),
#  (24, 3),
#  (25, 46),
#  (30, 4),
#  (32, 4),
#  (36, 3),
#  (38, 7),
#  (39, 4),
#  (40, 19),
#  (41, 1),
#  (42, 21),
#  (43, 12),
#  (44, 23),
#  (45, 63),
#  (46, 2),
#  (47, 3),
#  (48, 32),
#  (50, 33),
#  (51, 17),
#  (52, 2),
#  (54, 6),
#  (55, 2),
#  (56, 2),
#  (57, 41),
#  (58, 15),
#  (59, 2),
#  (60, 9),
#  (61, 19),
#  (62, 12),
#  (64, 2),
#  (65, 8),
#  (67, 12),
#  (68, 7),
#  (69, 3),
#  (70, 5),
#  (71, 2),
#  (72, 1),
#  (73, 8),
#  (74, 4),
#  (75, 4),
#  (77, 7),
#  (78, 1),
#  (80, 9),
#  (81, 2),
#  (82, 1),
#  (83, 2),
#  (84, 15),
#  (85, 3),
#  (86, 2),
#  (88, 7),
#  (90, 57),
#  (92, 1),
#  (93, 2),
#  (94, 3),
#  (95, 37),
#  (96, 5),
#  (308, 1),
#  (309, 3),
#  (311, 3),
#  (313, 2),
#  (315, 2),
#  (317, 3),
#  (318, 2),
#  (319, 9),
#  (320, 2),
#  (322, 1),
#  (328, 21),
#  (330, 2),
#  (331, 10),
#  (332, 3),
#  (333, 1),
#  (334, 8),
#  (339, 4),
#  (340, 10),
#  (341, 24),
#  (342, 3),
#  (343, 5),
#  (344, 68),
#  (346, 12),
#  (347, 26),
#  (348, 7),
#  (349, 4),
#  (350, 1),
#  (351, 6),
#  (353, 20),
#  (354, 8),
#  (356, 2),
#  (357, 1),
#  (359, 3),
#  (361, 7),
#  (362, 40),
#  (363, 20),
#  (367, 5),
#  (369, 100),
#  (370, 1),
#  (372, 7),
#  (373, 1),
#  (374, 11),
#  (375, 1),
#  (376, 5),
#  (377, 13),
#  (378, 16),
#  (379, 1),
#  (381, 23),
#  (382, 23),
#  (383, 42),
#  (384, 2),
#  (385, 24),
#  (386, 3),
#  (387, 6),
#  (388, 1),
#  (390, 10),
#  (391, 1),
#  (392, 2),
#  (394, 2),
#  (395, 1),
#  (396, 2),
#  (397, 2),
#  (398, 2),
#  (400, 14),
#  (402, 2),
#  (404, 2),
#  (406, 5),
#  (407, 1),
#  (409, 38),
#  (410, 11),
#  (411, 9),
#  (413, 1),
#  (414, 1),
#  (416, 2),
#  (417, 2),
#  (419, 2),
#  (420, 16),
#  (421, 3),
#  (422, 1),
#  (423, 6),
#  (424, 6),
#  (427, 3),
#  (428, 16),
#  (431, 2),
#  (432, 1),
#  (433, 2),
#  (434, 21),
#  (436, 4),
#  (437, 3),
#  (440, 5),
#  (443, 2),
#  (445, 7),
#  (448, 1),
#  (449, 26),
#  (451, 1),
#  (452, 1),
#  (453, 2),
#  (455, 2),
#  (459, 1),
#  (461, 4),
#  (464, 13),
#  (465, 1),
#  (467, 1),
#  (468, 3),
#  (470, 6),
#  (473, 5),
#  (475, 2),
#  (476, 2),
#  (479, 1),
#  (480, 19),
#  (484, 2),
#  (486, 9),
#  (489, 6),
#  (490, 1),
#  (494, 1),
#  (495, 1),
#  (497, 3),
#  (501, 1),
#  (502, 2),
#  (505, 2),
#  (509, 1),
#  (511, 2),
#  (512, 3),
#  (513, 1),
#  (516, 1),
#  (517, 2),
#  (520, 1),
#  (522, 2),
#  (524, 1),
#  (525, 2),
#  (526, 1),
#  (528, 1),
#  (532, 1),
#  (533, 1),
#  (534, 1),
#  (535, 1),
#  (541, 2),
#  (542, 1),
#  (543, 1),
#  (548, 2),
#  (549, 3),
#  (552, 1),
#  (554, 1),
#  (555, 1),
#  (557, 5),
#  (559, 2),
#  (561, 1),
#  (564, 2),
#  (565, 2),
#  (566, 1),
#  (567, 10),
#  (568, 1),
#  (569, 1),
#  (574, 1),
#  (578, 2),
#  (581, 51),
#  (582, 1),
#  (584, 1),
#  (586, 36),
#  (587, 1),
#  (591, 9),
#  (593, 2),
#  (594, 19),
#  (595, 1),
#  (598, 2),
#  (602, 1),
#  (603, 1),
#  (607, 37),
#  (608, 6),
#  (609, 1),
#  (611, 5),
#  (612, 1),
#  (614, 1),
#  (615, 2),
#  (617, 1),
#  (618, 1),
#  (620, 1),
#  (627, 2),
#  (630, 1),
#  (631, 5),
#  (632, 1),
#  (642, 1),
#  (646, 1),
#  (650, 8),
#  (654, 1),
#  (655, 2),
#  (656, 6),
#  (658, 1),
#  (659, 2),
#  (662, 1),
#  (667, 1),
#  (670, 1),
#  (672, 1),
#  (676, 2),
#  (682, 1),
#  (683, 5),
#  (686, 29),
#  (688, 4),
#  (692, 3),
#  (693, 1),
#  (700, 1),
#  (706, 2),
#  (712, 1),
#  (713, 1),
#  (714, 2),
#  (718, 2),
#  (721, 2),
#  (723, 4),
#  (724, 1),
#  (726, 2),
#  (727, 1),
#  (729, 9),
#  (730, 1),
#  (732, 1),
#  (733, 2),
#  (734, 1),
#  (737, 1),
#  (738, 1),
#  (740, 1),
#  (741, 1),
#  (742, 10),
#  (743, 1),
#  (744, 1),
#  (745, 1),
#  (747, 5),
#  (748, 5),
#  (749, 3),
#  (750, 2),
#  (751, 1),
#  (752, 1),
#  (754, 2),
#  (756, 1),
#  (757, 4),
#  (758, 2),
#  (759, 2),
#  (760, 3),
#  (764, 1),
#  (765, 2),
#  (766, 6),
#  (768, 1),
#  (770, 1),
#  (775, 3),
#  (777, 1),
#  (780, 3),
#  (784, 1),
#  (785, 3),
#  (786, 2),
#  (789, 2),
#  (791, 1),
#  (793, 1),
#  (794, 2),
#  (795, 2),
#  (796, 7),
#  (798, 3),
#  (799, 1),
#  (801, 2),
#  (802, 2),
#  (807, 2),
#  (809, 1),
#  (813, 1),
#  (814, 1),
#  (815, 3),
#  (817, 1),
#  (818, 2),
#  (825, 1),
#  (826, 2),
#  (828, 1),
#  (830, 2),
#  (834, 1),
#  (838, 2),
#  (840, 1),
#  (842, 8),
#  (843, 5),
#  (844, 3),
#  (846, 6),
#  (847, 2),
#  (848, 1),
#  (849, 1),
#  (851, 2),
#  (854, 1),
#  (856, 5),
#  (861, 1),
#  (862, 1),
#  (864, 1),
#  (865, 27),
#  (866, 7),
#  (867, 3),
#  (869, 16),
#  (870, 2),
#  (873, 5),
#  (878, 2),
#  (879, 4),
#  (881, 1),
#  (885, 1),
#  (887, 1),
#  (888, 1),
#  (889, 1),
#  (890, 1),
#  (891, 1),
#  (892, 1),
#  (893, 1),
#  (895, 1),
#  (896, 1),
#  (897, 2),
#  (903, 2),
#  (904, 1),
#  (908, 2),
#  (910, 1),
#  (911, 2),
#  (913, 1),
#  (914, 1),
#  (917, 47),
#  (918, 8),
#  (919, 1),
#  (921, 1),
#  (922, 2),
#  (924, 14),
#  (926, 1),
#  (929, 1),
#  (930, 16),
#  (931, 1),
#  (939, 2),
#  (940, 1),
#  (941, 5),
#  (943, 6),
#  (945, 4),
#  (946, 2),
#  (951, 1),
#  (953, 1),
#  (957, 1),
#  (959, 2),
#  (964, 1),
#  (976, 1),
#  (987, 1),
#  (988, 1),
#  (989, 13),
#  (990, 2),
#  (991, 4),
#  (992, 1),
#  (999, 2),
#  (1001, 1),
#  (1002, 2),
#  (1004, 3),
#  (1005, 1),
#  (1006, 1),
#  (1007, 2),
#  (1010, 3),
#  (1015, 1),
#  (1016, 1),
#  (1019, 14),
#  (1025, 4),
#  (1027, 13),
#  (1028, 2),
#  (1029, 1),
#  (1041, 2),
#  (1047, 6),
#  (1048, 1)]

# %%
# %%sql
# --Count of log events per user for the following verbs 2.viewed
# SELECT u.id,
#  COUNT(*) AS logins
# FROM mdl_logstore_standard_log l
# join mdl_user u on u.id = l.userid
# WHERE l.action = 
#  (503, 12),
#  (504, 12),
#  (505, 17),
#  (506, 12),
#  (507, 12),
#  (508, 12),
#  (509, 15),
#  (510, 12),
#  (511, 20),
#  (512, 32),
#  (513, 17),
#  (514, 12),
#  (515, 12),
#  (516, 16),
#  (517, 26),
#  (518, 12),
#  (519, 12),
#  (520, 28),
#  (521, 12),
#  (522, 33),
#  (523, 12),
#  (524, 14),
#  (525, 15),
#  (526, 13),
#  (527, 12),
#  (528, 13),
#  (529, 12),
#  (530, 12),
#  (531, 12),
#  (532, 16),
#  (533, 14),
#  (534, 26),
#  (535, 14),
#  (536, 12),
#  (537, 12),
#  (538, 12),
#  (539, 12),
#  (540, 12),
#  (541, 55),
#  (542, 13),
#  (543, 13),
#  (544, 12),
#  (545, 12),
#  (546, 12),
#  (547, 12),
#  (548, 52),
#  (549, 42),
#  (550, 12),
#  (551, 12),
#  (552, 20),
#  (553, 12),
#  (554, 17),
#  (555, 28),
#  (556, 12),
#  (557, 41),
#  (558, 12),
#  (559, 18),
#  (560, 12),
#  (561, 20),
#  (562, 12),
#  (563, 12),
#  (564, 19),
#  (565, 21),
#  (566, 17),
#  (567, 217),
#  (568, 15),
#  (569, 14),
#  (570, 12),
#  (571, 12),
#  (572, 12),
#  (573, 12),
#  (574, 15),
#  (575, 12),
#  (576, 12),
#  (577, 12),
#  (578, 14),
#  (579, 12),
#  (580, 12),
#  (581, 1041),
#  (582, 13),
#  (583, 12),
#  (584, 22),
#  (585, 12),
#  (586, 579),
#  (587, 18),
#  (588, 12),
#  (589, 12),
#  (590, 12),
#  (591, 110),
#  (592, 12),
#  (593, 71),
#  (594, 538),
#  (595, 19),
#  (596, 12),
#  (597, 12),
#  (598, 26),
#  (599, 12),
#  (600, 12),
#  (601, 12),
#  (602, 17),
#  (603, 22),
#  (604, 12),
#  (605, 12),
#  (606, 12),
#  (607, 371),
#  (608, 44),
#  (609, 14),
#  (610, 12),
#  (611, 138),
#  (612, 24),
#  (613, 12),
#  (614, 14),
#  (615, 75),
#  (616, 12),
#  (617, 15),
#  (618, 14),
#  (619, 12),
#  (620, 12),
#  (621, 12),
#  (622, 12),
#  (623, 12),
#  (624, 12),
#  (625, 12),
#  (626, 12),
#  (627, 18),
#  (628, 12),
#  (629, 12),
#  (630, 14),
#  (631, 60),
#  (632, 46),
#  (633, 12),
#  (634, 12),
#  (635, 12),
#  (636, 12),
#  (637, 12),
#  (638, 12),
#  (639, 12),
#  (640, 12),
#  (641, 12),
#  (642, 13),
#  (643, 12),
#  (644, 12),
#  (645, 12),
#  (646, 16),
#  (647, 12),
#  (648, 12),
#  (649, 12),
#  (650, 85),
#  (651, 12),
#  (652, 12),
#  (653, 12),
#  (654, 19),
#  (655, 14),
#  (656, 47),
#  (657, 12),
#  (658, 13),
#  (659, 30),
#  (660, 12),
#  (661, 12),
#  (662, 24),
#  (663, 12),
#  (664, 12),
#  (665, 12),
#  (666, 12),
#  (667, 28),
#  (668, 12),
#  (669, 12),
#  (670, 12),
#  (671, 12),
#  (672, 14),
#  (673, 12),
#  (674, 12),
#  (213, 9),
#  (214, 4),
#  (217, 17),
#  (219, 4),
#  (222, 3),
#  (223, 2),
#  (225, 5),
#  (227, 4),
#  (228, 25),
#  (232, 1),
#  (233, 3),
#  (234, 7),
#  (235, 1),
#  (236, 1),
#  (237, 2),
#  (239, 2),
#  (241, 5),
#  (242, 3),
#  (243, 1),
#  (244, 4),
#  (246, 36),
#  (247, 2),
#  (250, 7),
#  (253, 5),
#  (254, 9),
#  (255, 1),
#  (256, 5),
#  (258, 3),
#  (259, 17),
#  (260, 2),
#  (262, 9),
#  (263, 1),
#  (266, 25),
#  (268, 7),
#  (270, 1),
#  (271, 12),
#  (272, 5),
#  (274, 7),
#  (275, 3),
#  (277, 7),
#  (278, 7),
#  (280, 4),
#  (281, 1),
#  (282, 6),
#  (284, 18),
#  (286, 9),
#  (287, 1),
#  (289, 7),
#  (290, 26),
#  (291, 1),
#  (294, 13),
#  (295, 2),
#  (296, 2),
#  (297, 2),
#  (298, 1),
#  (299, 8),
#  (301, 7),
#  (303, 6),
#  (306, 6),
#  (307, 6),
#  (313, 1),
#  (317, 1),
#  (319, 4),
#  (328, 30),
#  (331, 6),
#  (332, 4),
#  (334, 1),
#  (339, 1),
#  (340, 23),
#  (341, 22),
#  (343, 4),
#  (344, 39),
#  (346, 4),
#  (347, 23),
#  (348, 6),
#  (349, 4),
#  (351, 8),
#  (353, 8),
#  (354, 4),
#  (356, 1),
#  (359, 1),
#  (361, 2),
#  (362, 13),
#  (363, 21),
#  (367, 1),
#  (369, 42),
#  (370, 1),
#  (372, 8),
#  (373, 3),
#  (374, 5),
#  (375, 6),
#  (376, 7),
#  (377, 26),
#  (378, 6),
#  (379, 4),
#  (381, 15),
#  (382, 27),
#  (383, 30),
#  (385, 30),
#  (386, 4),
#  (387, 18),
#  (390, 2),
#  (392, 2),
#  (394, 1),
#  (400, 7),
#  (404, 1),
#  (406, 2),
#  (409, 9),
#  (410, 5),
#  (411, 6),
#  (414, 2),
#  (419, 2),
#  (420, 9),
#  (421, 2),
#  (423, 2),
#  (424, 4),
#  (427, 17),
#  (428, 7),
#  (431, 2),
#  (434, 7),
#  (436, 5),
#  (437, 1),
#  (440, 5),
#  (443, 3),
#  (445, 4),
#  (448, 1),
#  (449, 17),
#  (453, 1),
#  (461, 4),
#  (464, 5),
#  (468, 4),
#  (470, 6),
#  (480, 28),
#  (484, 2),
#  (486, 7),
#  (489, 1),
#  (495, 2),
#  (502, 4),
#  (517, 1),
#  (534, 4),
#  (541, 6),
#  (548, 5),
#  (549, 1),
#  (552, 1),
#  (555, 3),
#  (567, 10),
#  (581, 59),
#  (586, 25),
#  (591, 9),
#  (593, 5),
#  (594, 9),
#  (607, 19),
#  (608, 4),
#  (615, 7),
#  (650, 6),
#  (662, 1),
#  (683, 2),
#  (686, 9),
#  (714, 2),
#  (718, 1),
#  (723, 6),
#  (724, 1),
#  (729, 5),
#  (733, 2),
#  (734, 4),
#  (737, 1),
#  (738, 2),
#  (742, 9),
#  (743, 1),
#  (747, 2),
#  (750, 6),
#  (757, 5),
#  (759, 1),
#  (760, 1),
#  (766, 2),
#  (770, 1),
#  (775, 5),
#  (777, 3),
#  (786, 4),
#  (789, 5),
#  (796, 4),
#  (799, 1),
#  (801, 2),
#  (813, 2),
#  (830, 3),
#  (838, 4),
#  (842, 7),
#  (843, 3),
#  (844, 3),
#  (846, 15),
#  (847, 1),
#  (848, 1),
#  (849, 4),
#  (856, 3),
#  (865, 21),
#  (866, 6),
#  (867, 1),
#  (879, 4),
#  (889, 1),
#  (897, 1),
#  (903, 1),
#  (911, 1),
#  (914, 3),
#  (917, 4),
#  (918, 16),
#  (922, 1),
#  (924, 27),
#  (930, 63),
#  (941, 5),
#  (943, 1),
#  (945, 6),
#  (989, 16),
#  (990, 1),
#  (999, 1),
#  (1001, 4),
#  (1004, 3),
#  (1015, 1),
#  (1019, 1),
#  (1025, 16),
#  (1027, 19),
#  (1041, 2),
#  (1047, 3)]

# %%
# %%sql
# --Count of log events per user for the following verbs 5.uploaded
# SELECT u.id,
#  COUNT(*) AS logins
# FROM mdl_logstore_standard_log l
# join mdl_user u on u.id = l.userid
# WHERE l.action = 'uploaded'
# group by u.id
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 71 rows affected.
# [(2, 21),
#  (3, 6),
#  (5, 1),
#  (42, 1),
#  (44, 1),
#  (45, 3),
#  (48, 4),
#  (50, 4),
#  (58, 2),
#  (61, 4),
#  (77, 1),
#  (88, 1),
#  (90, 3),
#  (98, 1),
#  (115, 1),
#  (118, 1),
#  (123, 1),
#  (146, 1),
#  (165, 4),
#  (167, 1),
#  (170, 3),
#  (201, 1),
#  (228, 1),
#  (234, 4),
#  (246, 14),
#  (250, 1),
#  (253, 1),
#  (259, 3),
#  (262, 1),
#  (266, 3),
#  (274, 3),
#  (290, 4),
#  (299, 2),
#  (328, 1),
#  (331, 1),
#  (340, 1),
#  (344, 3),
#  (347, 8),
#  (351, 1),
#  (353, 1),
#  (362, 1),
#  (363, 2),
#  (367, 1),
#  (369, 4),
#  (381, 1),
#  (382, 1),
#  (383, 5),
#  (385, 2),
#  (387, 1),
#  (409, 1),
#  (420, 1),
#  (428, 2),
#  (443, 1),
#  (449, 1),
#  (480, 3),
#  (512, 1),
#  (581, 4),
#  (586, 3),
#  (607, 1),
#  (615, 1),
#  (632, 1),
#  (686, 1),
#  (742, 3),
#  (756, 1),
#  (789, 1),
#  (794, 1),
#  (865, 2),
#  (879, 2),
#  (917, 3),
#  (924, 1),
#  (930, 1)]

# %%
# %%sql
# --Count of log events per user for the following verbs 6.updated
# SELECT u.id,
#  COUNT(*) AS logins
# FROM mdl_logstore_standard_log l
# join mdl_user u on u.id = l.userid
# WHERE l.action = 'updated'
# group by u.id
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 554 rows affected.
# [(2, 2551),
#  (3, 1467),
#  (5, 19),
#  (7, 1),
#  (8, 1),
#  (9, 16),
#  (15, 2),
#  (16, 3),
#  (19, 3),
#  (24, 1),
#  (25, 17),
#  (32, 2),
#  (36, 3),
#  (38, 9),
#  (39, 9),
#  (40, 10),
#  (41, 1),
#  (42, 56),
#  (43, 11),
#  (44, 20),
#  (45, 43),
#  (47, 2),
#  (48, 22),
#  (50, 27),
#  (51, 12),
#  (52, 2),
#  (54, 3),
#  (55, 1),
#  (56, 12),
#  (57, 12),
#  (58, 20),
#  (59, 2),
#  (60, 11),
#  (61, 19),
#  (62, 8),
#  (64, 1),
#  (65, 6),
#  (67, 6),
#  (68, 13),
#  (286, 14),
#  (287, 4),
#  (288, 3),
#  (289, 13),
#  (290, 73),
#  (291, 3),
#  (292, 1),
#  (293, 1),
#  (294, 22),
#  (295, 5),
#  (296, 5),
#  (297, 3),
#  (298, 4),
#  (299, 15),
#  (301, 15),
#  (302, 2),
#  (303, 6),
#  (305, 1),
#  (306, 9),
#  (307, 7),
#  (308, 1),
#  (311, 2),
#  (313, 4),
#  (315, 2),
#  (317, 2),
#  (318, 1),
#  (319, 5),
#  (320, 2),
#  (322, 1),
#  (328, 39),
#  (330, 1),
#  (331, 15),
#  (332, 5),
#  (333, 1),
#  (334, 5),
#  (339, 13),
#  (340, 51),
#  (341, 51),
#  (342, 2),
#  (343, 5),
#  (344, 59),
#  (346, 8),
#  (347, 60),
#  (348, 10),
#  (349, 8),
#  (350, 2),
#  (351, 17),
#  (353, 18),
#  (354, 8),
#  (356, 6),
#  (357, 1),
#  (359, 2),
#  (361, 7),
#  (362, 22),
#  (363, 37),
#  (367, 6),
#  (369, 82),
#  (370, 1),
#  (372, 16),
#  (373, 4),
#  (374, 9),
#  (375, 9),
#  (376, 15),
#  (377, 23),
#  (378, 18),
#  (379, 5),
#  (381, 29),
#  (382, 47),
#  (383, 79),
#  (384, 2),
#  (385, 67),
#  (386, 4),
#  (387, 39),
#  (388, 1),
#  (390, 6),
#  (391, 1),
#  (392, 6),
#  (394, 2),
#  (396, 1),
#  (397, 1),
#  (398, 1),
#  (400, 10),
#  (402, 3),
#  (404, 2),
#  (406, 4),
#  (407, 1),
#  (409, 34),
#  (410, 10),
#  (411, 13),
#  (413, 1),
#  (414, 3),
#  (417, 1),
#  (419, 3),
#  (420, 30),
#  (421, 3),
#  (422, 1),
#  (423, 3),
#  (424, 6),
#  (427, 18),
#  (428, 16),
#  (431, 3),
#  (432, 1),
#  (433, 1),
#  (434, 13),
#  (436, 6),
#  (437, 2),
#  (440, 13),
#  (443, 6),
#  (445, 6),
#  (448, 1),
#  (449, 17),
#  (451, 1),
#  (453, 5),
#  (459, 2),
#  (461, 5),
#  (464, 8),
#  (467, 1),
#  (468, 6),
#  (470, 11),
#  (473, 1),
#  (475, 1),
#  (480, 34),
#  (484, 3),
#  (486, 12),
#  (489, 7),
#  (490, 1),
#  (494, 1),
#  (495, 2),
#  (501, 1),
#  (502, 5),
#  (505, 2),
#  (509, 1),
#  (511, 1),
#  (512, 4),
#  (513, 3),
#  (517, 3),
#  (522, 11),
#  (524, 1),
#  (525, 1),
#  (526, 1),
#  (528, 1),
#  (532, 1),
#  (534, 5),
#  (535, 1),
#  (541, 7),
#  (542, 1),
#  (543, 1),
#  (548, 6),
#  (549, 8),
#  (552, 2),
#  (554, 3),
#  (555, 4),
#  (557, 5),
#  (559, 2),
#  (561, 1),
#  (564, 1),
#  (565, 1),
#  (566, 1),
#  (567, 12),
#  (574, 1),
#  (578, 1),
#  (581, 80),
#  (582, 1),
#  (584, 1),
#  (586, 62),
#  (587, 6),
#  (591, 22),
#  (593, 15),
#  (594, 23),
#  (595, 1),
#  (603, 1),
#  (607, 22),
#  (608, 5),
#  (611, 4),
#  (612, 2),
#  (615, 12),
#  (618, 1),
#  (630, 1),
#  (631, 6),
#  (632, 5),
#  (642, 1),
#  (646, 1),
#  (650, 5),
#  (654, 1),
#  (655, 1),
#  (656, 1),
#  (662, 2),
#  (667, 1),
#  (676, 2),
#  (683, 6),
#  (686, 18),
#  (688, 1),
#  (692, 1),
#  (700, 3),
#  (706, 1),
#  (712, 1),
#  (714, 5),
#  (718, 2),
#  (721, 6),
#  (723, 11),
#  (724, 2),
#  (726, 2),
#  (727, 1),
#  (729, 10),
#  (730, 1),
#  (732, 1),
#  (733, 3),
#  (734, 5),
#  (737, 3),
#  (738, 7),
#  (742, 17),
#  (743, 2),
#  (744, 2),
#  (745, 1),
#  (747, 2),
#  (748, 2),
#  (749, 1),
#  (750, 8),
#  (751, 1),
#  (752, 4),
#  (754, 2),
#  (756, 1),
#  (757, 8),
#  (758, 7),
#  (759, 2),
#  (760, 2),
#  (764, 1),
#  (765, 1),
#  (766, 3),
#  (768, 1),
#  (770, 4),
#  (775, 10),
#  (777, 2),
#  (780, 2),
#  (784, 1),
#  (785, 1),
#  (786, 2),
#  (789, 11),
#  (793, 1),
#  (794, 6),
#  (795, 1),
#  (796, 6),
#  (798, 1),
#  (799, 1),
#  (801, 2),
#  (802, 1),
#  (807, 1),
#  (809, 1),
#  (813, 5),
#  (815, 3),
#  (817, 1),
#  (826, 1),
#  (828, 1),
#  (830, 5),
#  (834, 1),
#  (838, 8),
#  (840, 1),
#  (842, 6),
#  (843, 9),
#  (844, 4),
#  (846, 17),
#  (847, 2),
#  (848, 1),
#  (849, 5),
#  (851, 1),
#  (854, 1),
#  (856, 4),
#  (861, 1),
#  (862, 1),
#  (864, 1),
#  (865, 33),
#  (866, 4),
#  (867, 2),
#  (869, 1),
#  (870, 1),
#  (873, 3),
#  (878, 1),
#  (879, 12),
#  (881, 1),
#  (885, 1),
#  (887, 1),
#  (888, 6),
#  (889, 2),
#  (890, 1),
#  (893, 23),
#  (895, 1),
#  (896, 1),
#  (897, 1),
#  (903, 2),
#  (904, 1),
#  (908, 1),
#  (910, 1),
#  (911, 3),
#  (913, 1),
#  (914, 7),
#  (917, 164),
#  (918, 26),
#  (919, 1),
#  (921, 1),
#  (922, 5),
#  (924, 63),
#  (926, 2),
#  (929, 1),
#  (930, 26),
#  (931, 1),
#  (939, 5),
#  (940, 1),
#  (941, 11),
#  (943, 2),
#  (945, 11),
#  (946, 1),
#  (951, 1),
#  (953, 1),
#  (957, 1),
#  (959, 1),
#  (976, 1),
#  (987, 1),
#  (988, 1),
#  (989, 39),
#  (990, 1),
#  (991, 5),
#  (992, 1),
#  (999, 2),
#  (1001, 5),
#  (1002, 1),
#  (1004, 4),
#  (1005, 2),
#  (1006, 2),
#  (1010, 1),
#  (1015, 2),
#  (1016, 1),
#  (1019, 5),
#  (1025, 24),
#  (1027, 43),
#  (1028, 1),
#  (1029, 6),
#  (1041, 6),
#  (1047, 4),
#  (1048, 1)]

# %%
# %%sql
# --Count of log events per user for the following verbs 7.searched
# SELECT u.id,
#  COUNT(*) AS logins
# FROM mdl_logstore_standard_log l
# join mdl_user u on u.id = l.userid
# WHERE l.action = 'searched'
# group by u.id
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 8 rows affected.
# [(84, 2), (246, 1), (253, 1), (266, 2), (294, 1), (347, 2), (385, 4), (586, 1)]

# %%
# %%sql
# --Count of log events per user for the following verbs 8.resumed
# SELECT u.id,
#  COUNT(*) AS logins
# FROM mdl_logstore_standard_log l
# join mdl_user u on u.id = l.userid
# WHERE l.action = 'resumed'
# group by u.id
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 235 rows affected.
# [(3, 4),
#  (5, 2),
#  (9, 1),
#  (25, 10),
#  (39, 4),
#  (40, 2),
#  (42, 6),
#  (43, 7),
#  (44, 8),
#  (45, 19),
#  (48, 14),
#  (50, 17),
#  (51, 21),
#  (56, 1),
#  (57, 13),
#  (58, 3),
#  (60, 3),
#  (61, 21),
#  (62, 2),
#  (67, 2),
#  (68, 2),
#  (73, 5),
#  (74, 1),
#  (75, 3),
#  (78, 7),
#  (80, 15),
#  (83, 1),
#  (84, 4),
#  (88, 1),
#  (90, 6),
#  (94, 2),
#  (95, 11),
#  (98, 10),
#  (99, 11),
#  (102, 4),
#  (103, 16),
#  (105, 1),
#  (107, 1),
#  (108, 2),
#  (115, 2),
#  (116, 1),
#  (118, 7),
#  (121, 2),
#  (123, 9),
#  (125, 1),
#  (126, 9),
#  (130, 7),
#  (131, 2),
#  (132, 7),
#  (133, 4),
#  (137, 1),
#  (138, 2),
#  (141, 3),
#  (143, 8),
#  (144, 11),
#  (145, 7),
#  (146, 4),
#  (147, 3),
#  (148, 5),
#  (149, 1),
#  (150, 1),
#  (156, 9),
#  (161, 18),
#  (165, 23),
#  (167, 8),
#  (168, 8),
#  (170, 6),
#  (174, 5),
#  (178, 1),
#  (179, 27),
#  (180, 2),
#  (182, 2),
#  (184, 1),
#  (185, 7),
#  (186, 1),
#  (189, 3),
#  (190, 10),
#  (194, 1),
#  (195, 1),
#  (201, 16),
#  (210, 23),
#  (211, 2),
#  (213, 1),
#  (217, 12),
#  (219, 1),
#  (221, 1),
#  (222, 3),
#  (223, 1),
#  (227, 2),
#  (228, 2),
#  (233, 5),
#  (234, 32),
#  (236, 1),
#  (237, 2),
#  (239, 2),
#  (241, 16),
#  (242, 9),
#  (244, 8),
#  (246, 23),
#  (250, 9),
#  (254, 13),
#  (255, 1),
#  (256, 1),
#  (258, 4),
#  (259, 16),
#  (262, 14),
#  (263, 1),
#  (266, 10),
#  (268, 34),
#  (270, 1),
#  (271, 1),
#  (274, 11),
#  (277, 14),
#  (278, 2),
#  (280, 2),
#  (282, 2),
#  (284, 23),
#  (286, 14),
#  (287, 1),
#  (289, 24),
#  (290, 19),
#  (294, 14),
#  (295, 4),
#  (296, 2),
#  (297, 7),
#  (298, 1),
#  (299, 10),
#  (301, 6),
#  (303, 2),
#  (306, 2),
#  (307, 1),
#  (319, 15),
#  (328, 9),
#  (331, 20),
#  (340, 5),
#  (341, 6),
#  (343, 1),
#  (344, 11),
#  (346, 7),
#  (347, 16),
#  (348, 13),
#  (349, 3),
#  (351, 3),
#  (353, 13),
#  (354, 1),
#  (356, 2),
#  (359, 2),
#  (362, 3),
#  (363, 1),
#  (369, 4),
#  (372, 1),
#  (374, 22),
#  (375, 1),
#  (376, 9),
#  (377, 10),
#  (378, 22),
#  (381, 1),
#  (382, 16),
#  (383, 11),
#  (385, 1),
#  (386, 3),
#  (400, 8),
#  (406, 2),
#  (409, 16),
#  (411, 8),
#  (414, 1),
#  (419, 1),
#  (420, 15),
#  (421, 3),
#  (423, 4),
#  (424, 9),
#  (427, 5),
#  (428, 4),
#  (440, 1),
#  (443, 1),
#  (445, 2),
#  (449, 6),
#  (464, 2),
#  (480, 1),
#  (484, 1),
#  (486, 7),
#  (512, 1),
#  (548, 2),
#  (549, 1),
#  (555, 1),
#  (567, 12),
#  (581, 12),
#  (586, 13),
#  (594, 9),
#  (598, 1),
#  (607, 5),
#  (608, 2),
#  (650, 2),
#  (656, 11),
#  (662, 1),
#  (676, 1),
#  (683, 1),
#  (686, 6),
#  (721, 2),
#  (723, 4),
#  (726, 3),
#  (730, 1),
#  (734, 1),
#  (737, 1),
#  (738, 1),
#  (747, 19),
#  (757, 6),
#  (760, 1),
#  (766, 1),
#  (796, 1),
#  (799, 1),
#  (825, 1),
#  (830, 1),
#  (843, 2),
#  (844, 1),
#  (856, 2),
#  (865, 4),
#  (866, 2),
#  (879, 3),
#  (903, 1),
#  (911, 1),
#  (917, 2),
#  (918, 3),
#  (919, 3),
#  (922, 1),
#  (939, 1),
#  (941, 9),
#  (943, 1),
#  (945, 1),
#  (989, 1),
#  (991, 1),
#  (999, 2),
#  (1004, 2),
#  (1027, 2),
#  (1047, 2)]

# %%
# %%sql
# --Count of log events per user for the following verbs 9.answered
# SELECT u.id,
#  COUNT(*) AS logins
# FROM mdl_logstore_standard_log l
# join mdl_user u on u.id = l.userid
# WHERE l.action = 'answered'
# group by u.id
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 165 rows affected.
# [(5, 2),
#  (9, 4),
#  (25, 6),
#  (38, 1),
#  (39, 1),
#  (40, 2),
#  (42, 2),
#  (43, 1),
#  (44, 3),
#  (45, 4),
#  (48, 3),
#  (50, 1),
#  (51, 1),
#  (56, 2),
#  (57, 5),
#  (58, 3),
#  (61, 4),
#  (67, 2),
#  (73, 2),
#  (74, 2),
#  (80, 2),
#  (85, 2),
#  (88, 2),
#  (90, 2),
#  (94, 1),
#  (95, 2),
#  (96, 1),
#  (99, 3),
#  (102, 1),
#  (103, 2),
#  (107, 4),
#  (115, 5),
#  (118, 1),
#  (123, 3),
#  (126, 2),
#  (127, 1),
#  (131, 1),
#  (132, 5),
#  (133, 7),
#  (135, 1),
#  (137, 1),
#  (138, 5),
#  (139, 1),
#  (141, 2),
#  (143, 3),
#  (145, 4),
#  (146, 3),
#  (147, 1),
#  (156, 7),
#  (165, 5),
#  (167, 1),
#  (168, 2),
#  (170, 5),
#  (174, 1),
#  (178, 1),
#  (179, 5),
#  (180, 1),
#  (184, 2),
#  (185, 5),
#  (186, 4),
#  (189, 1),
#  (190, 4),
#  (201, 1),
#  (209, 1),
#  (210, 2),
#  (213, 1),
#  (217, 6),
#  (222, 1),
#  (223, 1),
#  (228, 1),
#  (233, 3),
#  (234, 1),
#  (236, 1),
#  (241, 2),
#  (242, 6),
#  (244, 2),
#  (246, 3),
#  (250, 3),
#  (254, 3),
#  (255, 1),
#  (258, 2),
#  (259, 1),
#  (262, 1),
#  (263, 1),
#  (266, 3),
#  (268, 1),
#  (270, 1),
#  (271, 2),
#  (274, 2),
#  (277, 2),
#  (278, 3),
#  (284, 2),
#  (286, 1),
#  (289, 1),
#  (290, 3),
#  (291, 1),
#  (294, 2),
#  (295, 1),
#  (298, 2),
#  (299, 5),
#  (301, 3),
#  (328, 1),
#  (331, 5),
#  (340, 1),
#  (341, 1),
#  (344, 1),
#  (346, 1),
#  (347, 1),
#  (348, 1),
#  (349, 2),
#  (351, 1),
#  (353, 2),
#  (354, 2),
#  (356, 2),
#  (362, 1),
#  (363, 2),
#  (369, 2),
#  (372, 2),
#  (374, 2),
#  (375, 2),
#  (376, 1),
#  (377, 2),
#  (378, 2),
#  (381, 4),
#  (382, 1),
#  (383, 2),
#  (385, 1),
#  (392, 2),
#  (409, 2),
#  (411, 2),
#  (420, 2),
#  (428, 1),
#  (434, 2),
#  (440, 2),
#  (449, 2),
#  (453, 2),
#  (486, 1),
#  (489, 2),
#  (567, 3),
#  (581, 1),
#  (586, 2),
#  (594, 1),
#  (607, 1),
#  (683, 1),
#  (686, 4),
#  (721, 2),
#  (723, 1),
#  (738, 1),
#  (742, 2),
#  (752, 2),
#  (757, 2),
#  (813, 1),
#  (843, 1),
#  (865, 1),
#  (879, 4),
#  (914, 1),
#  (917, 2),
#  (918, 11),
#  (922, 1),
#  (924, 3),
#  (945, 2),
#  (989, 2),
#  (991, 1),
#  (1027, 1),
#  (1041, 1)]

# %%
# %%sql
# --Count of log events per user for the following verbs 10.attempted
# SELECT u.id,
#  COUNT(*) AS logins
# FROM mdl_logstore_standard_log l
# join mdl_user u on u.id = l.userid
# WHERE l.action = 'attempted'
# group by u.id
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 0 rows affected.
# []

# %%
# %%sql
# --Count of log events per user for the following verbs 11.abandoned
# SELECT u.id, COUNT(*) AS logins
# FROM mdl_logstore_standard_log l
# join mdl_user u on u.id = l.userid
# WHERE l.action = 'abandoned'
# group by u.id
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 1 rows affected.
# [(2, 5)]

# %% [markdown]
# 5. Counting of log events per user

# %% [markdown]
# Below we will count the log events per user for different verbs.
# The verbs are ['loggedin', 'viewed', 'started', ,'submitted', 'uploaded', 'updated', 'searched', 'resumed', 'answered', 'attempted', 'abandoned'].
#
# We will a short function to help us.

# %%
verbs = ['loggedin', 'viewed', 'started', 'submitted', 'uploaded', 'updated',
         'searched', 'resumed', 'answered', 'attempted', 'abandoned'] 
def actions_(verb_):
    results = %sql SELECT userid, COUNT(action) as total_actions_count FROM mdl_logstore_standard_log GROUP BY userid order by total_actions_count desc
    return results

# %%
#Calling the function and printing the results
data=actions_('abandoned_')

print('Results')
print('------------------')
data
# Out:
#  * postgresql://postgres:***@localhost/moodle1
# 1049 rows affected.
# Results
# ------------------
# [(2, 45023),
#  (246, 13917),
#  (3, 12922),
#  (917, 10696),
#  (581, 10533),
#  (290, 8558),
#  (347, 7320),
#  (0, 7257),
#  (607, 6461),
#  (344, 6019),
#  (165, 6015),
#  (228, 5063),
#  (201, 4964),
#  (42, 4916),
#  (90, 4644),
#  (369, 4608),
#  (328, 4297),
#  (45, 4241),
#  (480, 4232),
#  (742, 4220),
#  (95, 4004),
#  (266, 3902),
#  (586, 3857),
#  (77, 3832),
#  (879, 3725),
#  (786, 3692),
#  (377, 3459),
#  (1025, 3404),
#  (567, 3345),
#  (210, 3075),
#  (181, 83),
#  (320, 83),
#  (796, 83),
#  (122, 82),
#  (631, 82),
#  (224, 82),
#  (317, 82),
#  (205, 82),
#  (856, 81),
#  (269, 81),
#  (162, 80),
#  (66, 80),
#  (110, 80),
#  (248, 80),
#  (261, 80),
#  (245, 79),
#  (111, 79),
#  (370, 79),
#  (183, 79),
#  (154, 79),
#  (379, 79),
#  (49, 78),
#  (136, 78),
#  (1047, 77),
#  (251, 77),
#  (12, 76),
#  (218, 75),
#  (18, 74),
#  (342, 74),
#  (29, 74),
#  (212, 74),
#  (53, 73),
#  (276, 73),
#  (283, 73),
#  (943, 73),
#  (238, 73),
#  (142, 72),
#  (206, 72),
#  (63, 72),
#  (229, 72),
#  (300, 72),
#  (197, 72),
#  (79, 72),
#  (187, 71),
#  (384, 71),
#  (97, 71),
#  (37, 71),
#  (549, 71),
#  (89, 71),
#  (117, 71),
#  (990, 70),
#  (192, 70),
#  (230, 70),
#  (21, 70),
#  (726, 69),
#  (676, 69),
#  (91, 68),
#  (249, 68),
#  (388, 68),
#  (758, 68),
#  (1004, 68),
#  (257, 68),
#  (216, 68),
#  (23, 67),
#  (196, 67),
#  (177, 67),
#  (305, 66),
#  (330, 66),
#  (87, 66),
#  (173, 66),
#  (279, 66),
#  (893, 66),
#  (26, 65),
#  (1029, 65),
#  (315, 65),
#  (14, 64),
#  (473, 64),
#  (748, 64),
#  (714, 64),
#  (31, 63),
#  (27, 63),
#  (911, 63),
#  (17, 63),
#  (421, 62),
#  (555, 61),
#  (752, 61),
#  (557, 61),
#  (333, 61),
#  (13, 60),
#  (28, 60),
#  (461, 60),
#  (830, 60),
#  (522, 59),
#  (311, 59),
#  (368, 59),
#  (873, 57),
#  (807, 57),
#  (414, 56),
#  (8, 55),
#  (999, 55),
#  (939, 54),
#  (733, 54),
#  (818, 54),
#  (335, 54),
#  (867, 54),
#  (889, 53),
#  (326, 53),
#  (888, 53),
#  (512, 52),
#  (355, 52),
#  (316, 52),
#  (358, 52),
#  (903, 52),
#  (345, 52),
#  (878, 52),
#  (734, 52),
#  (350, 52),
#  (329, 52),
#  (380, 51),
#  (336, 51),
#  (404, 50),
#  (754, 50),
#  (431, 49),
#  (849, 49),
#  (534, 49),
#  (520, 48),
#  (321, 48),
#  (338, 48),
#  (365, 48),
#  (730, 47),
#  (322, 47),
#  (598, 47),
#  (324, 47),
#  (1001, 47),
#  (357, 47),
#  (770, 47),
#  (780, 46),
#  (737, 46),
#  (308, 46),
#  (394, 46),
#  (667, 45),
#  (815, 45),
#  (659, 45),
#  (318, 45),
#  (517, 44),
#  (847, 44),
#  (919, 43),
#  (765, 43),
#  (887, 43),
#  (688, 43),
#  (451, 43),
#  (419, 43),
#  (495, 43),
#  (323, 42),
#  (475, 42),
#  (662, 42),
#  (314, 42),
#  (325, 41),
#  (360, 41),
#  (312, 41),
#  (848, 41),
#  (706, 41),
#  (595, 41),
#  (799, 41),
#  (433, 41),
#  (310, 41),
#  (337, 41),
#  (931, 40),
#  (817, 40),
#  (417, 40),
#  (364, 40),
#  (612, 39),
#  (552, 38),
#  (825, 38),
#  (910, 38),
#  (371, 38),
#  (603, 38),
#  (352, 37),
#  (1028, 37),
#  (497, 37),
#  (327, 37),
#  (501, 37),
#  (366, 36),
#  (389, 36),
#  (494, 36),
#  (1010, 36),
#  (304, 36),
#  (459, 35),
#  (896, 35),
#  (764, 35),
#  (988, 35),
#  (565, 35),
#  (413, 35),
#  (511, 35),
#  (584, 34),
#  (802, 34),
#  (448, 34),
#  (654, 34),
#  (741, 34),
#  (940, 34),
#  (743, 33),
#  (718, 33),
#  (396, 33),
#  (1006, 33),
#  (559, 33),
#  (926, 32),
#  (513, 32),
#  (566, 32),
#  (476, 32),
#  (402, 32),
#  (395, 32),
#  (587, 32),
#  (1002, 31),
#  (564, 31),
#  (785, 31),
#  (525, 31),
#  (437, 31),
#  (745, 31),
#  (1048, 30),
#  (554, 30),
#  (617, 30),
#  (490, 29),
#  (535, 29),
#  (422, 29),
#  (795, 29),
#  (561, 29),
#  (407, 29),
#  (814, 29),
#  (398, 29),
#  (908, 29),
#  (897, 29),
#  (509, 29),
#  (885, 29),
#  (946, 28),
#  (870, 28),
#  (895, 28),
#  (1015, 28),
#  (862, 28),
#  (749, 28),
#  (397, 27),
#  (452, 27),
#  (505, 27),
#  (516, 27),
#  (602, 27),
#  (627, 27),
#  (670, 27),
#  (921, 27),
#  (971, 27),
#  (913, 26),
#  (416, 26),
#  (713, 26),
#  (1016, 26),
#  (574, 25),
#  (987, 25),
#  (712, 25),
#  (692, 25),
#  (732, 25),
#  (724, 25),
#  (957, 25),
#  (851, 25),
#  (904, 25),
#  (542, 24),
#  (569, 24),
#  (1005, 24),
#  (1007, 24),
#  (834, 24),
#  (432, 23),
#  (465, 23),
#  (828, 23),
#  (646, 23),
#  (630, 23),
#  (532, 23),
#  (658, 23),
#  (861, 22),
#  (568, 22),
#  (655, 22),
#  (976, 22),
#  (798, 22),
#  (953, 22),
#  (455, 22),
#  (890, 22),
#  (614, 22),
#  (618, 22),
#  (884, 22),
#  (533, 21),
#  (751, 21),
#  (700, 21),
#  (479, 21),
#  (959, 21),
#  (719, 20),
#  (543, 20),
#  (854, 20),
#  (578, 20),
#  (609, 20),
#  (642, 19),
#  (992, 19),
#  (582, 19),
#  (826, 19),
#  (809, 19),
#  (840, 19),
#  (526, 19),
#  (524, 19),
#  (929, 19),
#  (682, 18),
#  (528, 18),
#  (672, 18),
#  (467, 18),
#  (864, 18),
#  (727, 18),
#  (951, 17),
#  (955, 17),
#  (705, 17),
#  (722, 16),
#  (538, 16),
#  (793, 16),
#  (881, 16),
#  (707, 16),
#  (677, 15),
#  (970, 15),
#  (797, 15),
#  (619, 15),
#  (958, 15),
#  (634, 15),
#  (877, 14),
#  (986, 14),
#  (740, 14),
#  (968, 14),
#  (784, 14),
#  (588, 14),
#  (444, 14),
#  (915, 14),
#  (558, 14),
#  (661, 14),
#  (393, 14),
#  (835, 14),
#  (892, 14),
#  (493, 14),
#  (680, 14),
#  (403, 14),
#  (716, 14),
#  (899, 13),
#  (466, 13),
#  (993, 13),
#  (438, 12),
#  (435, 12),
#  (960, 12),
#  (430, 12),
#  (429, 12),
#  (426, 12),
#  (425, 12),
#  (418, 12),
#  (415, 12),
#  (412, 12),
#  (408, 12),
#  (1008, 12),
#  (405, 12),
#  (399, 12),
#  (1037, 12),
#  (613, 12),
#  (610, 12),
#  (938, 11),
#  (831, 11),
#  (829, 11),
#  (905, 11),
#  (906, 11),
#  (907, 11),
#  (739, 11),
#  (909, 11),
#  (805, 11),
#  (956, 11),
#  (804, 11),
#  (790, 11),
#  (788, 11),
#  (961, 11),
#  (962, 11),
#  (963, 11),
#  (787, 11),
#  (965, 11),
#  (966, 11),
#  (967, 11),
#  (782, 11),
#  (969, 11),
#  (781, 11),
#  (779, 11),
#  (778, 11),
#  (774, 11),
#  (1040, 11),
#  (772, 11),
#  (769, 11),
#  (767, 11),
#  (763, 11),
#  (762, 11),
#  (860, 11),
#  (859, 11),
#  (863, 11),
#  (858, 11),
#  (868, 11),
#  (761, 11),
#  (755, 11),
#  (871, 11),
#  (872, 11),
#  (874, 11),
#  (875, 11),
#  (876, 11),
#  (857, 11),
#  (855, 11),
#  (880, 11),
#  (853, 11),
#  (882, 11),
#  (753, 11),
#  (852, 11),
#  (886, 11),
#  (850, 11),
#  (845, 11),
#  (841, 11),
#  (839, 11),
#  (894, 11),
#  (836, 11),
#  (833, 11),
#  (898, 11),
#  (832, 11),
#  (900, 11),
#  (901, 11),
#  (912, 11),
#  (823, 11),
#  (746, 11),
#  (822, 11),
#  (916, 11),
#  (821, 11),
#  (820, 11),
#  (920, 11),
#  (923, 11),
#  (925, 11),
#  (927, 11),
#  (928, 11),
#  (819, 11),
#  (816, 11),
#  (932, 11),
#  (933, 11),
#  (934, 11),
#  (935, 11),
#  (936, 11),
#  (937, 11),
#  (902, 11),
#  (812, 11),
#  (942, 11),
#  (944, 11),
#  (810, 11),
#  (947, 11),
#  (948, 11),
#  (949, 11),
#  (950, 11),
#  (808, 11),
#  (952, 11),
#  (806, 11),
#  (954, 11),
#  (984, 10),
#  (985, 10),
#  (1017, 10),
#  (1000, 10),
#  (972, 10),
#  (1009, 10),
#  ...]

# %% [markdown]
# Querying to get the Overall grade of learners and Number of forum posts by connecting postgres database and using pandas to obtain data

# %%
# Establishing a connection to the database
host = "localhost" 
port = "5432" 
dbname = "moodle1"
user = "postgres"
pw = "Komboelvis01"
conn = psycopg2.connect(host=host, port=port, dbname=dbname, user=user, password=pw)
# Creating a cursor
cur = conn.cursor()

# A function that takes in a PostgreSQL query and outputs a pandas database 
def pull(sql_query, database = conn):
    table = pd.read_sql_query(sql_query, database)
    return table

# Utilize the create_pandas_table function to create a Pandas data frame
# Store the data as a variable

overall_grade = pull("select AVG(finalgrade) as overall_grade_of_learners from mdl_grade_grades")
print('Overall grade of learners ') 
print(overall_grade)
print('\n')

forum_posts = pull("select count(*) as number_of_forum_posts from mdl_forum_posts")
print('Number of forum posts')
print(forum_posts)

# Close the cursor and connection to so the server 

cur.close()
conn.close()
# Out:
# Overall grade of learners
#    overall_grade_of_learners
# 0                 107.371718
#
#
# Number of forum posts
#    number_of_forum_posts
# 0                    131
